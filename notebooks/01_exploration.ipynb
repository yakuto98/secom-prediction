# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load data
X = pd.read_csv('../data/secom.data', sep=' ', header=None)
y = pd.read_csv('../data/secom_labels.data', sep=' ', header=None)
y.columns = ['label', 'timestamp']

print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
print(f"\nClass distribution:")
print(y['label'].value_counts())
print(f"\nMissing values: {X.isnull().sum().sum():,}")
print(f"Missing ratio: {X.isnull().mean().mean():.1%}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4
#       5 # Load data
#       6 X = pd.read_csv('../data/secom.data', sep=' ', header=None)
#
# ModuleNotFoundError: No module named 'matplotlib'
